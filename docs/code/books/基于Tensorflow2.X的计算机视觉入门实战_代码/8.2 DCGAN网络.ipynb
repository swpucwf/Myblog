# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.losses import BinaryCrossentropy
import matplotlib.pyplot as plt 
import numpy as np
import PIL
import time
from IPython import display

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()   #读取mnist数据集

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')   #图像尺寸、类型转换
x_train = x_train[0:10000]   #选用前10000张作为训练集
x_train = x_train/255.0   #数据归一化

# %%
print(x_train.shape)
# Out:
# (10000, 28, 28, 1)

# %%
buffer_size = 30000
batch_size = 256   #一批次有256张图像

# %%
x_train = tf.data.Dataset.from_tensor_slices(x_train).shuffle(buffer_size).batch(batch_size)   #打乱数据集并分批

# %%
class DCGAN(tf.keras.Model):
    def __init__(self):
        super(DCGAN,self).__init__()
        self.Generator = tf.keras.models.Sequential([   #生成器网络
            layers.Dense(7*7*256),
            layers.BatchNormalization(),
            layers.LeakyReLU(),
            layers.Reshape((7,7,256)),
            layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same'),
            layers.BatchNormalization(),
            layers.LeakyReLU(),
            layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same'),
            layers.BatchNormalization(),
            layers.LeakyReLU(),
            layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same',activation='tanh'),
        ])
        self.Discriminator = tf.keras.models.Sequential([   #判别器网络
            layers.Conv2D(64,(5,5),strides=(2,2),padding='same'),
            layers.LeakyReLU(),
            layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'),
            layers.LeakyReLU(),
            layers.Flatten(),
            layers.Dense(1)
        ])

# %%
DCGAN = DCGAN()   #模型创建

# %%
z_distribution = tf.random.normal([1, 100])   #创建长度为1x100的随机正态分布向量

# %%
generated_image = DCGAN.Generator(z_distribution,training=False)   #调用生成器

# %%
plt.imshow(generated_image[0, :, :, 0], cmap='gray')   #查看生成的图片

# %%
dis_result = DCGAN.Discriminator(generated_image)   #调用判别器
print(dis_result)   #查看判别结果
# Out:
# tf.Tensor([[-0.00288183]], shape=(1, 1), dtype=float32)

# %%
binary_cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)   #调用损失函数

# %%
def discriminator_loss(real_output,fake_output):   #判别器损失函数
    #真实样本给予全1标签
    real_loss = binary_cross_entropy(tf.ones_like(real_output),real_output)   
    #生成样本给予全0标签
    fake_loss = binary_cross_entropy(tf.zeros_like(fake_output),fake_output)   
    total_loss = real_loss + fake_loss   #损失函数为以上二者之和
    return total_loss

# %%
def generator_loss(fake_output):   #生成器损失函数
    return binary_cross_entropy(tf.ones_like(fake_output),fake_output)   #生成样本给予全1标签

# %%
epochs = 60   #训练次数
z_distribution_dim = 100   #隐变量维度
generate_numbers = 12   #生成样本的数量
seed = tf.random.normal([generate_numbers, z_distribution_dim])   #用于测试的随机向量

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
def train_step(images,step):
    z_distribution = tf.random.normal([batch_size, z_distribution_dim])   #定义输入生成器的随机向量
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = DCGAN.Generator(z_distribution, training=True)   #生成图片
        #对真实样本进行判别
        real_output = DCGAN.Discriminator(images, training=True)
        #对生成样本进行判别
        fake_output = DCGAN.Discriminator(generated_images, training=True)
        gen_loss = generator_loss(fake_output)   #计算生成器损失
        disc_loss = discriminator_loss(real_output, fake_output)   #计算判别器损失
    #输出生成器和判别器的损失值
    print('Generator step {} loss is {}'.format(step,gen_loss))
    print('Discriminator step {} loss is {}'.format(step,disc_loss))
    #计算生成器和判别器的梯度并进行更新
    gradients_of_generator = gen_tape.gradient(gen_loss, DCGAN.Generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, DCGAN.Discriminator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, DCGAN.Generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, DCGAN.Discriminator.trainable_variables))

# %%
def generate_images(model,test_input):
    predictions = model(test_input, training=False)    #对seed变量输入进行预测
    fig = plt.figure(figsize=(4,4))
    for i in range(predictions.shape[0]):   #查看生成的图像，显示12张
        plt.subplot(3, 4, i+1)
        plt.imshow(predictions[i, :, :, 0] * 255, cmap='gray')
        plt.axis('off')
    plt.show()

# %%
def train(dataset, epochs):   #DCGAN模型训练函数
    for epoch in range(epochs):
        print("epoch:{}".format(epoch))
        step = 0   #记录在一次训练里的批次数
        start = time.time()
        for image_batch in dataset:   #逐批训练
            train_step(image_batch,step)
            step += 1
        print('Time for epoch {} is {} sec'.format(epoch,time.time()-start))   #训练一次的时间
        generate_images(DCGAN.Generator,seed)   #显示生成图像的变化

# %%
train(x_train, epochs)   #模型训练
# Out:
# epoch:0
# Generator step 0 loss is 0.7145646214485168
# Discriminator step 0 loss is 1.3695259094238281
# Generator step 1 loss is 0.7078595161437988
# Discriminator step 1 loss is 1.3664884567260742
# Generator step 2 loss is 0.7053114771842957
# Discriminator step 2 loss is 1.3590805530548096
# Generator step 3 loss is 0.7030126452445984
# Discriminator step 3 loss is 1.3525038957595825
# Generator step 4 loss is 0.7019749283790588
# Discriminator step 4 loss is 1.3440223932266235
# Generator step 5 loss is 0.7010701298713684
# Discriminator step 5 loss is 1.3393850326538086
# Generator step 6 loss is 0.7016545534133911
# Discriminator step 6 loss is 1.3289623260498047
# Generator step 7 loss is 0.7034330368041992
# Discriminator step 7 loss is 1.318274974822998
# Generator step 8 loss is 0.704522430896759
# Discriminator step 8 loss is 1.3110860586166382
# Generator step 9 loss is 0.7021980285644531
# Discriminator step 9 loss is 1.3071084022521973
# Generator step 10 loss is 0.6985713839530945
# Discriminator step 10 loss is 1.302215576171875
# Generator step 11 loss is 0.694898247718811
# Discriminator step 11 loss is 1.2968072891235352
# Generator step 12 loss is 0.6885851621627808
# Discriminator step 12 loss is 1.2989424467086792
# Generator step 13 loss is 0.6863359212875366
# Discriminator step 13 loss is 1.2948321104049683
# Generator step 14 loss is 0.6817606091499329
# Discriminator step 14 loss is 1.2934551239013672
# Generator step 15 loss is 0.6787949204444885
# Discriminator step 15 loss is 1.2934911251068115
# Generator step 16 loss is 0.6757616996765137
# Discriminator step 16 loss is 1.288341760635376
# Generator step 17 loss is 0.6718950271606445
# Discriminator step 17 loss is 1.292397379875183
# Generator step 18 loss is 0.6688181161880493
# Discriminator step 18 loss is 1.2890188694000244
# Generator step 19 loss is 0.664912223815918
# Discriminator step 19 loss is 1.2875568866729736
# Generator step 20 loss is 0.6616733074188232
# Discriminator step 20 loss is 1.288367748260498
# Generator step 21 loss is 0.6603879928588867
# Discriminator step 21 loss is 1.2927145957946777
# Generator step 22 loss is 0.6584869623184204
# Discriminator step 22 loss is 1.2889072895050049
# Generator step 23 loss is 0.6581096649169922
# Discriminator step 23 loss is 1.2866872549057007
# Generator step 24 loss is 0.6584359407424927
# Discriminator step 24 loss is 1.2874739170074463
# Generator step 25 loss is 0.6604745984077454
# Discriminator step 25 loss is 1.2817926406860352
# Generator step 26 loss is 0.6649090647697449
# Discriminator step 26 loss is 1.282135009765625
# Generator step 27 loss is 0.6713557243347168
# Discriminator step 27 loss is 1.2757987976074219
# Generator step 28 loss is 0.6791476011276245
# Discriminator step 28 loss is 1.270613193511963
# Generator step 29 loss is 0.6900689005851746
# Discriminator step 29 loss is 1.2601019144058228
# Generator step 30 loss is 0.7009260654449463
# Discriminator step 30 loss is 1.247706413269043
# Generator step 31 loss is 0.7127372026443481
# Discriminator step 31 loss is 1.2435007095336914
# Generator step 32 loss is 0.7254738807678223
# Discriminator step 32 loss is 1.2307159900665283
# Generator step 33 loss is 0.7374678254127502
# Discriminator step 33 loss is 1.2234675884246826
# Generator step 34 loss is 0.7481592297554016
# Discriminator step 34 loss is 1.2208908796310425
# Generator step 35 loss is 0.7576671242713928
# Discriminator step 35 loss is 1.213597297668457
# Generator step 36 loss is 0.7662402391433716
# Discriminator step 36 loss is 1.2134230136871338
# Generator step 37 loss is 0.776924192905426
# Discriminator step 37 loss is 1.2019360065460205
# Generator step 38 loss is 0.7867683172225952
# Discriminator step 38 loss is 1.1943814754486084
# Generator step 39 loss is 0.7969784736633301
# Discriminator step 39 loss is 1.1930694580078125
# Time for epoch 0 is 3.427168846130371 sec
# epoch:1
# Generator step 0 loss is 0.806751012802124
# Discriminator step 0 loss is 1.1867215633392334
# Generator step 1 loss is 0.817558765411377
# Discriminator step 1 loss is 1.1838316917419434
# Generator step 2 loss is 0.8261962532997131
# Discriminator step 2 loss is 1.1798574924468994
# Generator step 3 loss is 0.8341687321662903
# Discriminator step 3 loss is 1.1802031993865967
# Generator step 4 loss is 0.8402432799339294
# Discriminator step 4 loss is 1.1752873659133911
# Generator step 5 loss is 0.8449721336364746
# Discriminator step 5 loss is 1.1784498691558838
# Generator step 6 loss is 0.8454387187957764
# Discriminator step 6 loss is 1.1871109008789062
# Generator step 7 loss is 0.8427138924598694
# Discriminator step 7 loss is 1.1923813819885254
# Generator step 8 loss is 0.836929440498352
# Discriminator step 8 loss is 1.2000253200531006
# Generator step 9 loss is 0.8265010714530945
# Discriminator step 9 loss is 1.2134958505630493
# Generator step 10 loss is 0.8119107484817505
# Discriminator step 10 loss is 1.2301647663116455
# Generator step 11 loss is 0.8000056147575378
# Discriminator step 11 loss is 1.24220871925354
# Generator step 12 loss is 0.7924419045448303
# Discriminator step 12 loss is 1.25555419921875
# Generator step 13 loss is 0.7918133735656738
# Discriminator step 13 loss is 1.260995864868164
# Generator step 14 loss is 0.8001061081886292
# Discriminator step 14 loss is 1.2567248344421387
# Generator step 15 loss is 0.8160719871520996
# Discriminator step 15 loss is 1.2502936124801636
# Generator step 16 loss is 0.8376019597053528
# Discriminator step 16 loss is 1.2393312454223633
# Generator step 17 loss is 0.8622738122940063
# Discriminator step 17 loss is 1.223678708076477
# Generator step 18 loss is 0.8902146816253662
# Discriminator step 18 loss is 1.2027127742767334
# Generator step 19 loss is 0.9190674424171448
# Discriminator step 19 loss is 1.1920123100280762
# Generator step 20 loss is 0.9493976831436157
# Discriminator step 20 loss is 1.1707086563110352
# Generator step 21 loss is 0.9817603826522827
# Discriminator step 21 loss is 1.1525981426239014
# Generator step 22 loss is 1.0143667459487915
# Discriminator step 22 loss is 1.136730670928955
# Generator step 23 loss is 1.0468509197235107
# Discriminator step 23 loss is 1.119616150856018
# Generator step 24 loss is 1.0766807794570923
# Discriminator step 24 loss is 1.107844591140747
# Generator step 25 loss is 1.1024935245513916
# Discriminator step 25 loss is 1.0915651321411133
# Generator step 26 loss is 1.1235883235931396
# Discriminator step 26 loss is 1.0864810943603516
# Generator step 27 loss is 1.1431299448013306
# Discriminator step 27 loss is 1.0710052251815796
# Generator step 28 loss is 1.159030556678772
# Discriminator step 28 loss is 1.0554660558700562
# Generator step 29 loss is 1.1721549034118652
# Discriminator step 29 loss is 1.0467424392700195
# Generator step 30 loss is 1.1884965896606445
# Discriminator step 30 loss is 1.0411076545715332
# Generator step 31 loss is 1.1988292932510376
# Discriminator step 31 loss is 1.0392359495162964
# Generator step 32 loss is 1.2057325839996338
# Discriminator step 32 loss is 1.0431913137435913
# Generator step 33 loss is 1.2069889307022095
# Discriminator step 33 loss is 1.0243791341781616
# Generator step 34 loss is 1.205686330795288
# Discriminator step 34 loss is 1.028106451034546
# Generator step 35 loss is 1.207624912261963
# Discriminator step 35 loss is 1.0297503471374512
# Generator step 36 loss is 1.2156084775924683
# Discriminator step 36 loss is 1.0203388929367065
# Generator step 37 loss is 1.2316151857376099
# Discriminator step 37 loss is 1.0057353973388672
# Generator step 38 loss is 1.24528169631958
# Discriminator step 38 loss is 0.9926095008850098
# Generator step 39 loss is 1.2650036811828613
# Discriminator step 39 loss is 1.009141445159912
# Time for epoch 1 is 3.2230379581451416 sec
# epoch:2
# Generator step 0 loss is 1.280556082725525
# Discriminator step 0 loss is 0.9869613647460938
# Generator step 1 loss is 1.2976126670837402
# Discriminator step 1 loss is 0.9729742407798767
# Generator step 2 loss is 1.3145177364349365
# Discriminator step 2 loss is 0.9626182317733765
# Generator step 3 loss is 1.3324964046478271
# Discriminator step 3 loss is 0.9565452337265015
# Generator step 4 loss is 1.3502379655838013
# Discriminator step 4 loss is 0.9387182593345642
# Generator step 5 loss is 1.367948293685913
# Discriminator step 5 loss is 0.9295704364776611
# Generator step 6 loss is 1.3816299438476562
# Discriminator step 6 loss is 0.9343847036361694
# Generator step 7 loss is 1.392274022102356
# Discriminator step 7 loss is 0.92999267578125
# Generator step 8 loss is 1.4024076461791992
# Discriminator step 8 loss is 0.9166481494903564
# Generator step 9 loss is 1.4073388576507568
# Discriminator step 9 loss is 0.9171689748764038
# Generator step 10 loss is 1.4103260040283203
# Discriminator step 10 loss is 0.9024074077606201
# Generator step 11 loss is 1.411599040031433
# Discriminator step 11 loss is 0.9075089693069458
# Generator step 12 loss is 1.40872323513031
# Discriminator step 12 loss is 0.9066078662872314
# Generator step 13 loss is 1.3974897861480713
# Discriminator step 13 loss is 0.8969544172286987
# Generator step 14 loss is 1.384868860244751
# Discriminator step 14 loss is 0.9123547077178955
# Generator step 15 loss is 1.3636828660964966
# Discriminator step 15 loss is 0.9133915901184082
# Generator step 16 loss is 1.3463106155395508
# Discriminator step 16 loss is 0.9151245355606079
# Generator step 17 loss is 1.3301496505737305
# Discriminator step 17 loss is 0.9372110366821289
# Generator step 18 loss is 1.322990894317627
# Discriminator step 18 loss is 0.9156811237335205
# Generator step 19 loss is 1.326390266418457
# Discriminator step 19 loss is 0.9182381629943848
# Generator step 20 loss is 1.3429442644119263
# Discriminator step 20 loss is 0.9102309942245483
# Generator step 21 loss is 1.365869164466858
# Discriminator step 21 loss is 0.9073177576065063
# Generator step 22 loss is 1.393455982208252
# Discriminator step 22 loss is 0.8884139060974121
# Generator step 23 loss is 1.41824209690094
# Discriminator step 23 loss is 0.894206166267395
# Generator step 24 loss is 1.4384570121765137
# Discriminator step 24 loss is 0.8863561153411865
# Generator step 25 loss is 1.4530532360076904
# Discriminator step 25 loss is 0.8591996431350708
# Generator step 26 loss is 1.4607819318771362
# Discriminator step 26 loss is 0.854437530040741
# Generator step 27 loss is 1.4640551805496216
# Discriminator step 27 loss is 0.8523504137992859
# Generator step 28 loss is 1.4654595851898193
# Discriminator step 28 loss is 0.846880316734314
# Generator step 29 loss is 1.467589020729065
# Discriminator step 29 loss is 0.8575904369354248
# Generator step 30 loss is 1.4808385372161865
# Discriminator step 30 loss is 0.8486204743385315
# Generator step 31 loss is 1.4970394372940063
# Discriminator step 31 loss is 0.847599446773529
# Generator step 32 loss is 1.5252095460891724
# Discriminator step 32 loss is 0.8257103562355042
# Generator step 33 loss is 1.5546244382858276
# Discriminator step 33 loss is 0.8163901567459106
# Generator step 34 loss is 1.585120677947998
# Discriminator step 34 loss is 0.807606041431427
# Generator step 35 loss is 1.6129982471466064
# Discriminator step 35 loss is 0.8023456931114197
# Generator step 36 loss is 1.6383628845214844
# Discriminator step 36 loss is 0.7640308141708374
# Generator step 37 loss is 1.6511616706848145
# Discriminator step 37 loss is 0.7690893411636353
# Generator step 38 loss is 1.6602246761322021
# Discriminator step 38 loss is 0.7618874907493591
# Generator step 39 loss is 1.6578166484832764
# Discriminator step 39 loss is 0.7448234558105469
# Time for epoch 2 is 3.0087625980377197 sec
# epoch:3
# Generator step 0 loss is 1.6530482769012451
# Discriminator step 0 loss is 0.7372441291809082
# Generator step 1 loss is 1.6554847955703735
# Discriminator step 1 loss is 0.720979630947113
# Generator step 2 loss is 1.6501213312149048
# Discriminator step 2 loss is 0.7229829430580139
# Generator step 3 loss is 1.646881341934204
# Discriminator step 3 loss is 0.7234295606613159
# Generator step 4 loss is 1.639183521270752
# Discriminator step 4 loss is 0.7072209119796753
# Generator step 5 loss is 1.637697696685791
# Discriminator step 5 loss is 0.7027187347412109
# Generator step 6 loss is 1.623207926750183
# Discriminator step 6 loss is 0.7074652314186096
# Generator step 7 loss is 1.6119146347045898
# Discriminator step 7 loss is 0.7081893682479858
# Generator step 8 loss is 1.5851666927337646
# Discriminator step 8 loss is 0.7079123258590698
# Generator step 9 loss is 1.549338459968567
# Discriminator step 9 loss is 0.695305347442627
# Generator step 10 loss is 1.5126125812530518
# Discriminator step 10 loss is 0.7183834910392761
# Generator step 11 loss is 1.4867491722106934
# Discriminator step 11 loss is 0.7137526273727417
# Generator step 12 loss is 1.4773225784301758
# Discriminator step 12 loss is 0.7073092460632324
# Generator step 13 loss is 1.480072021484375
# Discriminator step 13 loss is 0.7130522131919861
# Generator step 14 loss is 1.5041007995605469
# Discriminator step 14 loss is 0.7056112289428711
# Generator step 15 loss is 1.5447109937667847
# Discriminator step 15 loss is 0.6840947866439819
# Generator step 16 loss is 1.5910369157791138
# Discriminator step 16 loss is 0.6736078262329102
# Generator step 17 loss is 1.6443593502044678
# Discriminator step 17 loss is 0.6503308415412903
# Generator step 18 loss is 1.6907484531402588
# Discriminator step 18 loss is 0.6494503617286682
# Generator step 19 loss is 1.7299048900604248
# Discriminator step 19 loss is 0.6356710195541382
# Generator step 20 loss is 1.7565093040466309
# Discriminator step 20 loss is 0.6321247816085815
# Generator step 21 loss is 1.7747944593429565
# Discriminator step 21 loss is 0.6247090101242065
# Generator step 22 loss is 1.7784923315048218
# Discriminator step 22 loss is 0.6253114342689514
# Generator step 23 loss is 1.7724618911743164
# Discriminator step 23 loss is 0.6137297749519348
# Generator step 24 loss is 1.7535243034362793
# Discriminator step 24 loss is 0.6229294538497925
# Generator step 25 loss is 1.7285404205322266
# Discriminator step 25 loss is 0.6275027394294739
# Generator step 26 loss is 1.699413537979126
# Discriminator step 26 loss is 0.6345159411430359
# Generator step 27 loss is 1.67275071144104
# Discriminator step 27 loss is 0.6326974630355835
# Generator step 28 loss is 1.649765133857727
# Discriminator step 28 loss is 0.6374526023864746
# Generator step 29 loss is 1.644385814666748
# Discriminator step 29 loss is 0.6454205513000488
# Generator step 30 loss is 1.6456692218780518
# Discriminator step 30 loss is 0.6467534899711609
# Generator step 31 loss is 1.6587709188461304
# Discriminator step 31 loss is 0.6351067423820496
# Generator step 32 loss is 1.675875186920166
# Discriminator step 32 loss is 0.6419968008995056
# Generator step 33 loss is 1.6971598863601685
# Discriminator step 33 loss is 0.6290367841720581
# Generator step 34 loss is 1.7332350015640259
# Discriminator step 34 loss is 0.6325735449790955
# Generator step 35 loss is 1.7740089893341064
# Discriminator step 35 loss is 0.6196909546852112
# Generator step 36 loss is 1.8258111476898193
# Discriminator step 36 loss is 0.6086826324462891
# Generator step 37 loss is 1.8909635543823242
# Discriminator step 37 loss is 0.6089974641799927
# Generator step 38 loss is 1.9614098072052002
# Discriminator step 38 loss is 0.5910915732383728
# Generator step 39 loss is 2.031827449798584
# Discriminator step 39 loss is 0.5730174779891968
# Time for epoch 3 is 3.020880937576294 sec
# epoch:4
# Generator step 0 loss is 2.093317747116089
# Discriminator step 0 loss is 0.5696699023246765
# Generator step 1 loss is 2.13633131980896
# Discriminator step 1 loss is 0.5793116688728333
# Generator step 2 loss is 2.1606643199920654
# Discriminator step 2 loss is 0.5871274471282959
# Generator step 3 loss is 2.1611080169677734
# Discriminator step 3 loss is 0.5526027679443359
# Generator step 4 loss is 2.136395215988159
# Discriminator step 4 loss is 0.5615096092224121
# Generator step 5 loss is 2.099782943725586
# Discriminator step 5 loss is 0.5401583313941956
# Generator step 6 loss is 2.0425543785095215
# Discriminator step 6 loss is 0.5562259554862976
# Generator step 7 loss is 1.9879237413406372
# Discriminator step 7 loss is 0.5634787082672119
# Generator step 8 loss is 1.918205976486206
# Discriminator step 8 loss is 0.573176383972168
# Generator step 9 loss is 1.8497222661972046
# Discriminator step 9 loss is 0.5635461807250977
# Generator step 10 loss is 1.7861297130584717
# Discriminator step 10 loss is 0.570923924446106
# Generator step 11 loss is 1.7394630908966064
# Discriminator step 11 loss is 0.5584613084793091
# Generator step 12 loss is 1.7067737579345703
# Discriminator step 12 loss is 0.5711756944656372
# Generator step 13 loss is 1.6829301118850708
# Discriminator step 13 loss is 0.5757719278335571
# Generator step 14 loss is 1.6721770763397217
# Discriminator step 14 loss is 0.575992226600647
# Generator step 15 loss is 1.6716504096984863
# Discriminator step 15 loss is 0.5770856142044067
# Generator step 16 loss is 1.6922388076782227
# Discriminator step 16 loss is 0.5598679184913635
# Generator step 17 loss is 1.6962850093841553
# Discriminator step 17 loss is 0.5720610618591309
# Generator step 18 loss is 1.7015646696090698
# Discriminator step 18 loss is 0.5655502080917358
# Generator step 19 loss is 1.66683030128479
# Discriminator step 19 loss is 0.5918198227882385
# Generator step 20 loss is 1.6381009817123413
# Discriminator step 20 loss is 0.5881521105766296
# Generator step 21 loss is 1.6307480335235596
# Discriminator step 21 loss is 0.5963926315307617
# Generator step 22 loss is 1.5870020389556885
# Discriminator step 22 loss is 0.6340003609657288
# Generator step 23 loss is 1.5082015991210938
# Discriminator step 23 loss is 0.662988543510437
# Generator step 24 loss is 1.487877607345581
# Discriminator step 24 loss is 0.6875085830688477
# Generator step 25 loss is 1.4355741739273071
# Discriminator step 25 loss is 0.7071278691291809
# Generator step 26 loss is 1.4081435203552246
# Discriminator step 26 loss is 0.7390108108520508
# Generator step 27 loss is 1.3505439758300781
# Discriminator step 27 loss is 0.7523514032363892
# Generator step 28 loss is 1.357734203338623
# Discriminator step 28 loss is 0.7824091911315918
# Generator step 29 loss is 1.3059734106063843
# Discriminator step 29 loss is 0.8049184679985046
# Generator step 30 loss is 1.3010859489440918
# Discriminator step 30 loss is 0.8237284421920776
# Generator step 31 loss is 1.3173186779022217
# Discriminator step 31 loss is 0.8393229246139526
# Generator step 32 loss is 1.3007304668426514
# Discriminator step 32 loss is 0.8692749738693237
# Generator step 33 loss is 1.277867078781128
# Discriminator step 33 loss is 0.882584810256958
# Generator step 34 loss is 1.2609624862670898
# Discriminator step 34 loss is 0.9078829288482666
# Generator step 35 loss is 1.2904942035675049
# Discriminator step 35 loss is 0.9257116913795471
# Generator step 36 loss is 1.294909119606018
# Discriminator step 36 loss is 0.9475421905517578
# Generator step 37 loss is 1.3288522958755493
# Discriminator step 37 loss is 0.9791215062141418
# Generator step 38 loss is 1.3499813079833984
# Discriminator step 38 loss is 0.9993045926094055
# Generator step 39 loss is 1.3698054552078247
# Discriminator step 39 loss is 0.8741607666015625
# Time for epoch 4 is 2.9852311611175537 sec
# epoch:5
# Generator step 0 loss is 1.3957679271697998
# Discriminator step 0 loss is 0.9999858140945435
# Generator step 1 loss is 1.419810175895691
# Discriminator step 1 loss is 1.0117506980895996
# Generator step 2 loss is 1.4350218772888184
# Discriminator step 2 loss is 1.0367372035980225
# Generator step 3 loss is 1.3951315879821777
# Discriminator step 3 loss is 1.036824107170105
# Generator step 4 loss is 1.4183964729309082
# Discriminator step 4 loss is 0.9962519407272339
# Generator step 5 loss is 1.3443104028701782
# Discriminator step 5 loss is 1.0478096008300781
# Generator step 6 loss is 1.2997664213180542
# Discriminator step 6 loss is 1.0326203107833862
# Generator step 7 loss is 1.3203957080841064
# Discriminator step 7 loss is 0.9785089492797852
# Generator step 8 loss is 1.2160930633544922
# Discriminator step 8 loss is 1.0246405601501465
# Generator step 9 loss is 1.201642632484436
# Discriminator step 9 loss is 1.0595250129699707
# Generator step 10 loss is 1.1748629808425903
# Discriminator step 10 loss is 0.9916814565658569
# Generator step 11 loss is 1.1714938879013062
# Discriminator step 11 loss is 0.9655659794807434
# Generator step 12 loss is 1.1852301359176636
# Discriminator step 12 loss is 0.949324369430542
# Generator step 13 loss is 1.1325879096984863
# Discriminator step 13 loss is 0.9881174564361572
# Generator step 14 loss is 1.1300396919250488
# Discriminator step 14 loss is 0.9625365734100342
# Generator step 15 loss is 1.1196844577789307
# Discriminator step 15 loss is 0.9681849479675293
# Generator step 16 loss is 1.1184699535369873
# Discriminator step 16 loss is 0.9436143636703491
# Generator step 17 loss is 1.088526964187622
# Discriminator step 17 loss is 0.9978801608085632
# Generator step 18 loss is 1.1142889261245728
# Discriminator step 18 loss is 0.9450370669364929
# Generator step 19 loss is 1.1209381818771362
# Discriminator step 19 loss is 0.9059544801712036
# Generator step 20 loss is 1.126476526260376
# Discriminator step 20 loss is 0.9109095931053162
# Generator step 21 loss is 1.1373634338378906
# Discriminator step 21 loss is 0.9179691076278687
# Generator step 22 loss is 1.1410953998565674
# Discriminator step 22 loss is 0.9261417388916016
# Generator step 23 loss is 1.1297045946121216
# Discriminator step 23 loss is 0.9174526929855347
# Generator step 24 loss is 1.1343193054199219
# Discriminator step 24 loss is 0.9358904361724854
# Generator step 25 loss is 1.1628724336624146
# Discriminator step 25 loss is 0.9167752861976624
# Generator step 26 loss is 1.167389988899231
# Discriminator step 26 loss is 0.8931920528411865
# Generator step 27 loss is 1.18657386302948
# Discriminator step 27 loss is 0.9143878817558289
# Generator step 28 loss is 1.1989489793777466
# Discriminator step 28 loss is 0.8837324380874634
# Generator step 29 loss is 1.2175719738006592
# Discriminator step 29 loss is 0.8906053304672241
# Generator step 30 loss is 1.2426105737686157
# Discriminator step 30 loss is 0.8756746649742126
# Generator step 31 loss is 1.255989909172058
# Discriminator step 31 loss is 0.9114384651184082
# Generator step 32 loss is 1.2629326581954956
# Discriminator step 32 loss is 0.8788306713104248
# Generator step 33 loss is 1.2823293209075928
# Discriminator step 33 loss is 0.8607689738273621
# Generator step 34 loss is 1.3127179145812988
# Discriminator step 34 loss is 0.8797322511672974
# Generator step 35 loss is 1.3041211366653442
# Discriminator step 35 loss is 0.9007970094680786
# Generator step 36 loss is 1.332091212272644
# Discriminator step 36 loss is 0.8762201070785522
# Generator step 37 loss is 1.330411434173584
# Discriminator step 37 loss is 0.8755887746810913
# Generator step 38 loss is 1.3933978080749512
# Discriminator step 38 loss is 0.8517833948135376
# Generator step 39 loss is 1.3599777221679688
# Discriminator step 39 loss is 0.823346734046936
# Time for epoch 5 is 2.9681003093719482 sec
# epoch:6
# Generator step 0 loss is 1.3421341180801392
# Discriminator step 0 loss is 0.8708151578903198
# Generator step 1 loss is 1.3069148063659668
# Discriminator step 1 loss is 0.8913547992706299
# Generator step 2 loss is 1.2635407447814941
# Discriminator step 2 loss is 0.9239428639411926
# Generator step 3 loss is 1.225684404373169
# Discriminator step 3 loss is 0.9295044541358948
# Generator step 4 loss is 1.2163275480270386
# Discriminator step 4 loss is 0.8934892416000366
# Generator step 5 loss is 1.1727244853973389
# Discriminator step 5 loss is 0.9308161735534668
# Generator step 6 loss is 1.1017746925354004
# Discriminator step 6 loss is 0.9851338863372803
# Generator step 7 loss is 1.0839543342590332
# Discriminator step 7 loss is 0.9667848348617554
# Generator step 8 loss is 1.0918458700180054
# Discriminator step 8 loss is 0.9484790563583374
# Generator step 9 loss is 1.0728024244308472
# Discriminator step 9 loss is 0.9937565326690674
# Generator step 10 loss is 1.0672842264175415
# Discriminator step 10 loss is 0.9776033759117126
# Generator step 11 loss is 1.075766921043396
# Discriminator step 11 loss is 0.9672510623931885
# Generator step 12 loss is 1.0778809785842896
# Discriminator step 12 loss is 1.0113487243652344
# Generator step 13 loss is 1.0859633684158325
# Discriminator step 13 loss is 0.996380090713501
# Generator step 14 loss is 1.0844578742980957
# Discriminator step 14 loss is 0.9989705085754395
# Generator step 15 loss is 1.0732848644256592
# Discriminator step 15 loss is 1.0219873189926147
# Generator step 16 loss is 1.0268833637237549
# Discriminator step 16 loss is 1.0519163608551025
# Generator step 17 loss is 1.044140338897705
# Discriminator step 17 loss is 1.0376189947128296
# Generator step 18 loss is 1.0127067565917969
# Discriminator step 18 loss is 1.04963219165802
# Generator step 19 loss is 1.0124472379684448
# Discriminator step 19 loss is 1.0483640432357788
# Generator step 20 loss is 0.9976021647453308
# Discriminator step 20 loss is 1.06699538230896
# Generator step 21 loss is 0.9712578058242798
# Discriminator step 21 loss is 1.0811729431152344
# Generator step 22 loss is 0.9590008854866028
# Discriminator step 22 loss is 1.0868611335754395
# Generator step 23 loss is 0.9284669756889343
# Discriminator step 23 loss is 1.0958069562911987
# Generator step 24 loss is 0.9271710515022278
# Discriminator step 24 loss is 1.1222529411315918
# Generator step 25 loss is 0.9096367359161377
# Discriminator step 25 loss is 1.1027178764343262
# Generator step 26 loss is 0.8883315324783325
# Discriminator step 26 loss is 1.1317867040634155
# Generator step 27 loss is 0.888830304145813
# Discriminator step 27 loss is 1.1532690525054932
# Generator step 28 loss is 0.8836246728897095
# Discriminator step 28 loss is 1.111605167388916
# Generator step 29 loss is 0.8739931583404541
# Discriminator step 29 loss is 1.1359506845474243
# Generator step 30 loss is 0.873145341873169
# Discriminator step 30 loss is 1.12369966506958
# Generator step 31 loss is 0.8700207471847534
# Discriminator step 31 loss is 1.1388630867004395
# Generator step 32 loss is 0.8672870397567749
# Discriminator step 32 loss is 1.1398744583129883
# Generator step 33 loss is 0.8638629913330078
# Discriminator step 33 loss is 1.1278616189956665
# Generator step 34 loss is 0.862038254737854
# Discriminator step 34 loss is 1.134795069694519
# Generator step 35 loss is 0.8626453280448914
# Discriminator step 35 loss is 1.127333164215088
# Generator step 36 loss is 0.8635762929916382
# Discriminator step 36 loss is 1.1197127103805542
# Generator step 37 loss is 0.8462124466896057
# Discriminator step 37 loss is 1.1312026977539062
# Generator step 38 loss is 0.8460826277732849
# Discriminator step 38 loss is 1.151979684829712
# Generator step 39 loss is 0.8430503606796265
# Discriminator step 39 loss is 1.1006593704223633
# Time for epoch 6 is 3.0099422931671143 sec
# epoch:7
# Generator step 0 loss is 0.825797975063324
# Discriminator step 0 loss is 1.1189885139465332
# Generator step 1 loss is 0.8286258578300476
# Discriminator step 1 loss is 1.1453726291656494
# Generator step 2 loss is 0.825104832649231
# Discriminator step 2 loss is 1.15198814868927
# Generator step 3 loss is 0.8047386407852173
# Discriminator step 3 loss is 1.184680461883545
# Generator step 4 loss is 0.7994197607040405
# Discriminator step 4 loss is 1.1378357410430908
# Generator step 5 loss is 0.7842822074890137
# Discriminator step 5 loss is 1.1443699598312378
# Generator step 6 loss is 0.7837889790534973
# Discriminator step 6 loss is 1.135657548904419
# Generator step 7 loss is 0.7733726501464844
# Discriminator step 7 loss is 1.1686450242996216
# Generator step 8 loss is 0.7682000994682312
# Discriminator step 8 loss is 1.1519441604614258
# Generator step 9 loss is 0.7625528573989868
# Discriminator step 9 loss is 1.1901037693023682
# Generator step 10 loss is 0.7638428211212158
# Discriminator step 10 loss is 1.125035285949707
# Generator step 11 loss is 0.7600371837615967
# Discriminator step 11 loss is 1.1577095985412598
# Generator step 12 loss is 0.7540233135223389
# Discriminator step 12 loss is 1.1481338739395142
# Generator step 13 loss is 0.7596288919448853
# Discriminator step 13 loss is 1.1613306999206543
# Generator step 14 loss is 0.7576923966407776
# Discriminator step 14 loss is 1.1597495079040527
# Generator step 15 loss is 0.7609775066375732
# Discriminator step 15 loss is 1.177931547164917
# Generator step 16 loss is 0.769232988357544
# Discriminator step 16 loss is 1.155214548110962
# Generator step 17 loss is 0.7763890027999878
# Discriminator step 17 loss is 1.1466476917266846
# Generator step 18 loss is 0.7773024439811707
# Discriminator step 18 loss is 1.1452747583389282
# Generator step 19 loss is 0.7873400449752808
# Discriminator step 19 loss is 1.1585724353790283
# Generator step 20 loss is 0.8011899590492249
# Discriminator step 20 loss is 1.147157073020935
# Generator step 21 loss is 0.8033276200294495
# Discriminator step 21 loss is 1.1485401391983032
# Generator step 22 loss is 0.8138302564620972
# Discriminator step 22 loss is 1.1270322799682617
# Generator step 23 loss is 0.8198390007019043
# Discriminator step 23 loss is 1.126174807548523
# Generator step 24 loss is 0.8214751482009888
# Discriminator step 24 loss is 1.1458780765533447
# Generator step 25 loss is 0.8322228193283081
# Discriminator step 25 loss is 1.1393985748291016
# Generator step 26 loss is 0.8280749320983887
# Discriminator step 26 loss is 1.1135913133621216
# Generator step 27 loss is 0.8389610052108765
# Discriminator step 27 loss is 1.1191651821136475
# Generator step 28 loss is 0.8380073308944702
# Discriminator step 28 loss is 1.1178743839263916
# Generator step 29 loss is 0.8403591513633728
# Discriminator step 29 loss is 1.1161437034606934
# Generator step 30 loss is 0.8206671476364136
# Discriminator step 30 loss is 1.1173532009124756
# Generator step 31 loss is 0.8307956457138062
# Discriminator step 31 loss is 1.1116783618927002
# Generator step 32 loss is 0.8248385190963745
# Discriminator step 32 loss is 1.1094824075698853
# Generator step 33 loss is 0.8266013860702515
# Discriminator step 33 loss is 1.1044987440109253
# Generator step 34 loss is 0.8087232112884521
# Discriminator step 34 loss is 1.1061874628067017
# Generator step 35 loss is 0.7953824996948242
# Discriminator step 35 loss is 1.0885471105575562
# Generator step 36 loss is 0.7955196499824524
# Discriminator step 36 loss is 1.1121704578399658
# Generator step 37 loss is 0.7948223948478699
# Discriminator step 37 loss is 1.0887670516967773
# Generator step 38 loss is 0.8032638430595398
# Discriminator step 38 loss is 1.0858556032180786
# Generator step 39 loss is 0.792374312877655
# Discriminator step 39 loss is 1.1176038980484009
# Time for epoch 7 is 3.0146753787994385 sec
# epoch:8
# Generator step 0 loss is 0.7972788214683533
# Discriminator step 0 loss is 1.078621745109558
# Generator step 1 loss is 0.7953447699546814
# Discriminator step 1 loss is 1.0767810344696045
# Generator step 2 loss is 0.8012980222702026
# Discriminator step 2 loss is 1.058499813079834
# Generator step 3 loss is 0.7981444001197815
# Discriminator step 3 loss is 1.08943510055542
# Generator step 4 loss is 0.805400013923645
# Discriminator step 4 loss is 1.0765893459320068
# Generator step 5 loss is 0.8007374405860901
# Discriminator step 5 loss is 1.068158507347107
# Generator step 6 loss is 0.8037517070770264
# Discriminator step 6 loss is 1.0619033575057983
# Generator step 7 loss is 0.8056442141532898
# Discriminator step 7 loss is 1.0652694702148438
# Generator step 8 loss is 0.8035091757774353
# Discriminator step 8 loss is 1.0644081830978394
# Generator step 9 loss is 0.8001911044120789
# Discriminator step 9 loss is 1.0648260116577148
# Generator step 10 loss is 0.796470046043396
# Discriminator step 10 loss is 1.0646883249282837
# Generator step 11 loss is 0.7980243563652039
# Discriminator step 11 loss is 1.0637787580490112
# Generator step 12 loss is 0.7827385067939758
# Discriminator step 12 loss is 1.094007968902588
# Generator step 13 loss is 0.7716605067253113
# Discriminator step 13 loss is 1.0810415744781494
# Generator step 14 loss is 0.7662148475646973
# Discriminator step 14 loss is 1.107036828994751
# Generator step 15 loss is 0.7524352669715881
# Discriminator step 15 loss is 1.0984690189361572
# Generator step 16 loss is 0.7413017749786377
# Discriminator step 16 loss is 1.1125624179840088
# Generator step 17 loss is 0.7234007120132446
# Discriminator step 17 loss is 1.100363850593567
# Generator step 18 loss is 0.7099549770355225
# Discriminator step 18 loss is 1.1494019031524658
# Generator step 19 loss is 0.7060555219650269
# Discriminator step 19 loss is 1.1638346910476685
# Generator step 20 loss is 0.7022342681884766
# Discriminator step 20 loss is 1.1772582530975342
# Generator step 21 loss is 0.7015311121940613
# Discriminator step 21 loss is 1.1584231853485107
# Generator step 22 loss is 0.7084031105041504
# Discriminator step 22 loss is 1.1655811071395874
# Generator step 23 loss is 0.7115975022315979
# Discriminator step 23 loss is 1.1648415327072144
# Generator step 24 loss is 0.7177694439888
# Discriminator step 24 loss is 1.1799262762069702
# Generator step 25 loss is 0.726114809513092
# Discriminator step 25 loss is 1.1894960403442383
# Generator step 26 loss is 0.7363482713699341
# Discriminator step 26 loss is 1.1694810390472412
# Generator step 27 loss is 0.7443594932556152
# Discriminator step 27 loss is 1.2113823890686035
# Generator step 28 loss is 0.7571050524711609
# Discriminator step 28 loss is 1.1771725416183472
# Generator step 29 loss is 0.7654297351837158
# Discriminator step 29 loss is 1.1852612495422363
# Generator step 30 loss is 0.7762870788574219
# Discriminator step 30 loss is 1.1980160474777222
# Generator step 31 loss is 0.784264087677002
# Discriminator step 31 loss is 1.1545093059539795
# Generator step 32 loss is 0.7952955365180969
# Discriminator step 32 loss is 1.1365389823913574
# Generator step 33 loss is 0.8040896058082581
# Discriminator step 33 loss is 1.1174452304840088
# Generator step 34 loss is 0.807370126247406
# Discriminator step 34 loss is 1.1067769527435303
# Generator step 35 loss is 0.8113134503364563
# Discriminator step 35 loss is 1.0863585472106934
# Generator step 36 loss is 0.8096343874931335
# Discriminator step 36 loss is 1.0753732919692993
# Generator step 37 loss is 0.8059322834014893
# Discriminator step 37 loss is 1.0772392749786377
# Generator step 38 loss is 0.7944338917732239
# Discriminator step 38 loss is 1.0697743892669678
# Generator step 39 loss is 0.7854405045509338
# Discriminator step 39 loss is 1.1255953311920166
# Time for epoch 8 is 3.003364324569702 sec
# epoch:9
# Generator step 0 loss is 0.7651023864746094
# Discriminator step 0 loss is 1.0902304649353027
# Generator step 1 loss is 0.7508462071418762
# Discriminator step 1 loss is 1.0637656450271606
# Generator step 2 loss is 0.7147303223609924
# Discriminator step 2 loss is 1.0735429525375366
# Generator step 3 loss is 0.6932166814804077
# Discriminator step 3 loss is 1.0941828489303589
# Generator step 4 loss is 0.6777001619338989
# Discriminator step 4 loss is 1.1045918464660645
# Generator step 5 loss is 0.6622166633605957
# Discriminator step 5 loss is 1.1150951385498047
# Generator step 6 loss is 0.6540900468826294
# Discriminator step 6 loss is 1.1670715808868408
# Generator step 7 loss is 0.6548734903335571
# Discriminator step 7 loss is 1.1581449508666992
# Generator step 8 loss is 0.6661997437477112
# Discriminator step 8 loss is 1.1667115688323975
# Generator step 9 loss is 0.6844826936721802
# Discriminator step 9 loss is 1.1559545993804932
# Generator step 10 loss is 0.6910184621810913
# Discriminator step 10 loss is 1.1835687160491943
# Generator step 11 loss is 0.7011843919754028
# Discriminator step 11 loss is 1.216164231300354
# Generator step 12 loss is 0.7134958505630493
# Discriminator step 12 loss is 1.1969006061553955
# Generator step 13 loss is 0.7275855541229248
# Discriminator step 13 loss is 1.2283108234405518
# Generator step 14 loss is 0.7275376319885254
# Discriminator step 14 loss is 1.2478365898132324
# Generator step 15 loss is 0.7335084676742554
# Discriminator step 15 loss is 1.292386531829834
# Generator step 16 loss is 0.7263585925102234
# Discriminator step 16 loss is 1.3064409494400024
# Generator step 17 loss is 0.7335285544395447
# Discriminator step 17 loss is 1.2981427907943726
# Generator step 18 loss is 0.7411017417907715
# Discriminator step 18 loss is 1.2962394952774048
# Generator step 19 loss is 0.7506083250045776
# Discriminator step 19 loss is 1.3283096551895142
# Generator step 20 loss is 0.7591707706451416
# Discriminator step 20 loss is 1.348663330078125
# Generator step 21 loss is 0.7885521650314331
# Discriminator step 21 loss is 1.3290305137634277
# Generator step 22 loss is 0.8054210543632507
# Discriminator step 22 loss is 1.3145039081573486
# Generator step 23 loss is 0.8286643624305725
# Discriminator step 23 loss is 1.3063385486602783
# Generator step 24 loss is 0.8582820296287537
# Discriminator step 24 loss is 1.3534116744995117
# Generator step 25 loss is 0.8736439943313599
# Discriminator step 25 loss is 1.3801236152648926
# Generator step 26 loss is 0.9011560082435608
# Discriminator step 26 loss is 1.2582039833068848
# Generator step 27 loss is 0.904541552066803
# Discriminator step 27 loss is 1.2617353200912476
# Generator step 28 loss is 0.9111204147338867
# Discriminator step 28 loss is 1.2439978122711182
# Generator step 29 loss is 0.9208394289016724
# Discriminator step 29 loss is 1.2316505908966064
# Generator step 30 loss is 0.930103063583374
# Discriminator step 30 loss is 1.2023303508758545
# Generator step 31 loss is 0.9364805817604065
# Discriminator step 31 loss is 1.188215732574463
# Generator step 32 loss is 0.943606972694397
# Discriminator step 32 loss is 1.1779193878173828
# Generator step 33 loss is 0.9517448544502258
# Discriminator step 33 loss is 1.156195878982544
# Generator step 34 loss is 0.9703105092048645
# Discriminator step 34 loss is 1.1337158679962158
# Generator step 35 loss is 0.9759052991867065
# Discriminator step 35 loss is 1.1227467060089111
# Generator step 36 loss is 0.970935583114624
# Discriminator step 36 loss is 1.1109853982925415
# Generator step 37 loss is 0.9595052599906921
# Discriminator step 37 loss is 1.0800418853759766
# Generator step 38 loss is 0.949104368686676
# Discriminator step 38 loss is 1.0903444290161133
# Generator step 39 loss is 0.9378674030303955
# Discriminator step 39 loss is 1.2628297805786133
# Time for epoch 9 is 3.0613670349121094 sec
# epoch:10
# Generator step 0 loss is 0.9196239709854126
# Discriminator step 0 loss is 1.1232503652572632
# Generator step 1 loss is 0.9041438102722168
# Discriminator step 1 loss is 1.1183488368988037
# Generator step 2 loss is 0.893332302570343
# Discriminator step 2 loss is 1.1185173988342285
# Generator step 3 loss is 0.8998710513114929
# Discriminator step 3 loss is 1.1211504936218262
# Generator step 4 loss is 0.8966733813285828
# Discriminator step 4 loss is 1.1244468688964844
# Generator step 5 loss is 0.9079521894454956
# Discriminator step 5 loss is 1.1155321598052979
# Generator step 6 loss is 0.9220161437988281
# Discriminator step 6 loss is 1.1266610622406006
# Generator step 7 loss is 0.943207859992981
# Discriminator step 7 loss is 1.1054695844650269
# Generator step 8 loss is 0.9701563119888306
# Discriminator step 8 loss is 1.1083728075027466
# Generator step 9 loss is 0.9710633754730225
# Discriminator step 9 loss is 1.108198881149292
# Generator step 10 loss is 0.9871426224708557
# Discriminator step 10 loss is 1.127194881439209
# Generator step 11 loss is 0.9765587449073792
# Discriminator step 11 loss is 1.1378544569015503
# Generator step 12 loss is 0.963458776473999
# Discriminator step 12 loss is 1.1619683504104614
# Generator step 13 loss is 0.9321125745773315
# Discriminator step 13 loss is 1.1529974937438965
# Generator step 14 loss is 0.9012502431869507
# Discriminator step 14 loss is 1.196244478225708
# Generator step 15 loss is 0.8615332245826721
# Discriminator step 15 loss is 1.1900982856750488
# Generator step 16 loss is 0.8197677731513977
# Discriminator step 16 loss is 1.1894352436065674
# Generator step 17 loss is 0.7965704798698425
# Discriminator step 17 loss is 1.264650821685791
# Generator step 18 loss is 0.7630914449691772
# Discriminator step 18 loss is 1.267464280128479
# Generator step 19 loss is 0.7438187599182129
# Discriminator step 19 loss is 1.2768062353134155
# Generator step 20 loss is 0.7239388823509216
# Discriminator step 20 loss is 1.3226438760757446
# Generator step 21 loss is 0.7251615524291992
# Discriminator step 21 loss is 1.3565653562545776
# Generator step 22 loss is 0.7152218818664551
# Discriminator step 22 loss is 1.3639113903045654
# Generator step 23 loss is 0.7227227091789246
# Discriminator step 23 loss is 1.361490249633789
# Generator step 24 loss is 0.7274903655052185
# Discriminator step 24 loss is 1.4032585620880127
# Generator step 25 loss is 0.7326805591583252
# Discriminator step 25 loss is 1.4350733757019043
# Generator step 26 loss is 0.7476058006286621
# Discriminator step 26 loss is 1.3872867822647095
# Generator step 27 loss is 0.7606918811798096
# Discriminator step 27 loss is 1.4053021669387817
# Generator step 28 loss is 0.762127161026001
# Discriminator step 28 loss is 1.4138717651367188
# Generator step 29 loss is 0.7763315439224243
# Discriminator step 29 loss is 1.435567855834961
# Generator step 30 loss is 0.7739507555961609
# Discriminator step 30 loss is 1.4335582256317139
# Generator step 31 loss is 0.7718568444252014
# Discriminator step 31 loss is 1.443127155303955
# Generator step 32 loss is 0.7606468200683594
# Discriminator step 32 loss is 1.4227287769317627
# Generator step 33 loss is 0.7515751123428345
# Discriminator step 33 loss is 1.425102949142456
# Generator step 34 loss is 0.7371177077293396
# Discriminator step 34 loss is 1.5035761594772339
# Generator step 35 loss is 0.7194681167602539
# Discriminator step 35 loss is 1.4681437015533447
# Generator step 36 loss is 0.703325629234314
# Discriminator step 36 loss is 1.4579715728759766
# Generator step 37 loss is 0.6849619746208191
# Discriminator step 37 loss is 1.4702823162078857
# Generator step 38 loss is 0.6810091733932495
# Discriminator step 38 loss is 1.4880690574645996
# Generator step 39 loss is 0.6816734075546265
# Discriminator step 39 loss is 1.4934930801391602
# Time for epoch 10 is 3.0885205268859863 sec
# epoch:11
# Generator step 0 loss is 0.681675910949707
# Discriminator step 0 loss is 1.4920775890350342
# Generator step 1 loss is 0.6873986124992371
# Discriminator step 1 loss is 1.4904240369796753
# Generator step 2 loss is 0.7071527242660522
# Discriminator step 2 loss is 1.4552830457687378
# Generator step 3 loss is 0.7221225500106812
# Discriminator step 3 loss is 1.476611852645874
# Generator step 4 loss is 0.7381818890571594
# Discriminator step 4 loss is 1.441474199295044
# Generator step 5 loss is 0.7607080936431885
# Discriminator step 5 loss is 1.4576812982559204
# Generator step 6 loss is 0.7857253551483154
# Discriminator step 6 loss is 1.4736533164978027
# Generator step 7 loss is 0.8062789440155029
# Discriminator step 7 loss is 1.4194278717041016
# Generator step 8 loss is 0.8313615322113037
# Discriminator step 8 loss is 1.372509479522705
# Generator step 9 loss is 0.8298109769821167
# Discriminator step 9 loss is 1.3535635471343994
# Generator step 10 loss is 0.8488919734954834
# Discriminator step 10 loss is 1.3925613164901733
# Generator step 11 loss is 0.8732331395149231
# Discriminator step 11 loss is 1.363029956817627
# Generator step 12 loss is 0.8739076852798462
# Discriminator step 12 loss is 1.3118467330932617
# Generator step 13 loss is 0.8672444224357605
# Discriminator step 13 loss is 1.3531463146209717
# Generator step 14 loss is 0.8707045316696167
# Discriminator step 14 loss is 1.2687737941741943
# Generator step 15 loss is 0.8727421164512634
# Discriminator step 15 loss is 1.2705955505371094
# Generator step 16 loss is 0.8542225956916809
# Discriminator step 16 loss is 1.2711923122406006
# Generator step 17 loss is 0.8559705018997192
# Discriminator step 17 loss is 1.2053661346435547
# Generator step 18 loss is 0.8590560555458069
# Discriminator step 18 loss is 1.212994933128357
# Generator step 19 loss is 0.8449071645736694
# Discriminator step 19 loss is 1.181853175163269
# Generator step 20 loss is 0.8438827395439148
# Discriminator step 20 loss is 1.2121328115463257
# Generator step 21 loss is 0.8448408842086792
# Discriminator step 21 loss is 1.1685314178466797
# Generator step 22 loss is 0.8508739471435547
# Discriminator step 22 loss is 1.1830765008926392
# Generator step 23 loss is 0.8301881551742554
# Discriminator step 23 loss is 1.1845108270645142
# Generator step 24 loss is 0.8343050479888916
# Discriminator step 24 loss is 1.1810462474822998
# Generator step 25 loss is 0.8103117942810059
# Discriminator step 25 loss is 1.21095871925354
# Generator step 26 loss is 0.8043578267097473
# Discriminator step 26 loss is 1.205749750137329
# Generator step 27 loss is 0.801803708076477
# Discriminator step 27 loss is 1.1907222270965576
# Generator step 28 loss is 0.7820621728897095
# Discriminator step 28 loss is 1.2089745998382568
# Generator step 29 loss is 0.7705085277557373
# Discriminator step 29 loss is 1.2478811740875244
# Generator step 30 loss is 0.7592976093292236
# Discriminator step 30 loss is 1.271960735321045
# Generator step 31 loss is 0.7450926303863525
# Discriminator step 31 loss is 1.2406930923461914
# Generator step 32 loss is 0.7378761768341064
# Discriminator step 32 loss is 1.264191746711731
# Generator step 33 loss is 0.7248383164405823
# Discriminator step 33 loss is 1.2914003133773804
# Generator step 34 loss is 0.7174768447875977
# Discriminator step 34 loss is 1.3141846656799316
# Generator step 35 loss is 0.7198677062988281
# Discriminator step 35 loss is 1.3187187910079956
# Generator step 36 loss is 0.7244458198547363
# Discriminator step 36 loss is 1.3353567123413086
# Generator step 37 loss is 0.713556170463562
# Discriminator step 37 loss is 1.34531831741333
# Generator step 38 loss is 0.7144800424575806
# Discriminator step 38 loss is 1.3502745628356934
# Generator step 39 loss is 0.722237229347229
# Discriminator step 39 loss is 1.2599732875823975
# Time for epoch 11 is 3.0041885375976562 sec
# epoch:12
# Generator step 0 loss is 0.7280136942863464
# Discriminator step 0 loss is 1.344780683517456
# Generator step 1 loss is 0.7285504341125488
# Discriminator step 1 loss is 1.3551756143569946
# Generator step 2 loss is 0.7405139207839966
# Discriminator step 2 loss is 1.3417117595672607
# Generator step 3 loss is 0.7401626706123352
# Discriminator step 3 loss is 1.355120301246643
# Generator step 4 loss is 0.7480140328407288
# Discriminator step 4 loss is 1.3176701068878174
# Generator step 5 loss is 0.7547179460525513
# Discriminator step 5 loss is 1.3411576747894287
# Generator step 6 loss is 0.7587222456932068
# Discriminator step 6 loss is 1.3407286405563354
# Generator step 7 loss is 0.756969690322876
# Discriminator step 7 loss is 1.3176648616790771
# Generator step 8 loss is 0.7497328519821167
# Discriminator step 8 loss is 1.3432202339172363
# Generator step 9 loss is 0.7384834885597229
# Discriminator step 9 loss is 1.3074712753295898
# Generator step 10 loss is 0.7427341938018799
# Discriminator step 10 loss is 1.3215863704681396
# Generator step 11 loss is 0.7253915667533875
# Discriminator step 11 loss is 1.343631386756897
# Generator step 12 loss is 0.7243697643280029
# Discriminator step 12 loss is 1.2979538440704346
# Generator step 13 loss is 0.716565728187561
# Discriminator step 13 loss is 1.301561713218689
# Generator step 14 loss is 0.717927098274231
# Discriminator step 14 loss is 1.2848069667816162
# Generator step 15 loss is 0.7115622758865356
# Discriminator step 15 loss is 1.3207204341888428
# Generator step 16 loss is 0.7105560302734375
# Discriminator step 16 loss is 1.3318772315979004
# Generator step 17 loss is 0.7139005064964294
# Discriminator step 17 loss is 1.312974452972412
# Generator step 18 loss is 0.7149022817611694
# Discriminator step 18 loss is 1.328068494796753
# Generator step 19 loss is 0.718987226486206
# Discriminator step 19 loss is 1.310689926147461
# Generator step 20 loss is 0.7286622524261475
# Discriminator step 20 loss is 1.3572924137115479
# Generator step 21 loss is 0.726810097694397
# Discriminator step 21 loss is 1.3465266227722168
# Generator step 22 loss is 0.7482584118843079
# Discriminator step 22 loss is 1.3128736019134521
# Generator step 23 loss is 0.7435296177864075
# Discriminator step 23 loss is 1.3823621273040771
# Generator step 24 loss is 0.750942587852478
# Discriminator step 24 loss is 1.346527338027954
# Generator step 25 loss is 0.7489824295043945
# Discriminator step 25 loss is 1.3915642499923706
# Generator step 26 loss is 0.7567367553710938
# Discriminator step 26 loss is 1.4158016443252563
# Generator step 27 loss is 0.7512063384056091
# Discriminator step 27 loss is 1.362788438796997
# Generator step 28 loss is 0.7439762949943542
# ...
# Generator step 32 loss is 1.67894446849823
# Discriminator step 32 loss is 0.3742259442806244
# Generator step 33 loss is 1.8643769025802612
# Discriminator step 33 loss is 0.3789346218109131
# Generator step 34 loss is 2.1777522563934326
# Discriminator step 34 loss is 0.4416143596172333
# Generator step 35 loss is 2.143864154815674
# Discriminator step 35 loss is 0.4023582339286804
# Generator step 36 loss is 1.8886771202087402
# Discriminator step 36 loss is 0.4470599889755249
# Generator step 37 loss is 1.5759637355804443
# Discriminator step 37 loss is 0.44174501299858093
# Generator step 38 loss is 1.674464225769043
# Discriminator step 38 loss is 0.42505693435668945
# Generator step 39 loss is 2.0219693183898926
# Discriminator step 39 loss is 0.3977954387664795
# Time for epoch 55 is 3.0763914585113525 sec
# epoch:56
# Generator step 0 loss is 2.3188765048980713
# Discriminator step 0 loss is 0.4076632261276245
# Generator step 1 loss is 2.178224563598633
# Discriminator step 1 loss is 0.42400139570236206
# Generator step 2 loss is 1.6912741661071777
# Discriminator step 2 loss is 0.43327099084854126
# Generator step 3 loss is 1.6014459133148193
# Discriminator step 3 loss is 0.4402933120727539
# Generator step 4 loss is 1.7529380321502686
# Discriminator step 4 loss is 0.4153810143470764
# Generator step 5 loss is 2.1645193099975586
# Discriminator step 5 loss is 0.4303918778896332
# Generator step 6 loss is 2.2424423694610596
# Discriminator step 6 loss is 0.42557480931282043
# Generator step 7 loss is 1.910172939300537
# Discriminator step 7 loss is 0.397064208984375
# Generator step 8 loss is 1.750604510307312
# Discriminator step 8 loss is 0.4080125689506531
# Generator step 9 loss is 1.7316516637802124
# Discriminator step 9 loss is 0.41184014081954956
# Generator step 10 loss is 2.019894599914551
# Discriminator step 10 loss is 0.39315924048423767
# Generator step 11 loss is 2.154587507247925
# Discriminator step 11 loss is 0.42341184616088867
# Generator step 12 loss is 2.027787923812866
# Discriminator step 12 loss is 0.36987775564193726
# Generator step 13 loss is 1.8720817565917969
# Discriminator step 13 loss is 0.4233952760696411
# Generator step 14 loss is 1.7649389505386353
# Discriminator step 14 loss is 0.4253489673137665
# Generator step 15 loss is 1.8519278764724731
# Discriminator step 15 loss is 0.41182100772857666
# Generator step 16 loss is 2.001016855239868
# Discriminator step 16 loss is 0.38443073630332947
# Generator step 17 loss is 2.166341543197632
# Discriminator step 17 loss is 0.39877933263778687
# Generator step 18 loss is 2.016326665878296
# Discriminator step 18 loss is 0.38772574067115784
# Generator step 19 loss is 1.7811020612716675
# Discriminator step 19 loss is 0.42962801456451416
# Generator step 20 loss is 1.7914828062057495
# Discriminator step 20 loss is 0.4078945517539978
# Generator step 21 loss is 1.944126009941101
# Discriminator step 21 loss is 0.39911872148513794
# Generator step 22 loss is 2.0893189907073975
# Discriminator step 22 loss is 0.4159954786300659
# Generator step 23 loss is 2.0859601497650146
# Discriminator step 23 loss is 0.40778324007987976
# Generator step 24 loss is 1.7898966073989868
# Discriminator step 24 loss is 0.4031923711299896
# Generator step 25 loss is 1.7895718812942505
# Discriminator step 25 loss is 0.409898579120636
# Generator step 26 loss is 1.9811911582946777
# Discriminator step 26 loss is 0.40304481983184814
# Generator step 27 loss is 1.9901704788208008
# Discriminator step 27 loss is 0.3868215084075928
# Generator step 28 loss is 2.0785458087921143
# Discriminator step 28 loss is 0.3946189880371094
# Generator step 29 loss is 2.0019843578338623
# Discriminator step 29 loss is 0.3790418207645416
# Generator step 30 loss is 1.9422099590301514
# Discriminator step 30 loss is 0.387336403131485
# Generator step 31 loss is 1.8610167503356934
# Discriminator step 31 loss is 0.41622018814086914
# Generator step 32 loss is 1.9028187990188599
# Discriminator step 32 loss is 0.3984510898590088
# Generator step 33 loss is 1.903280258178711
# Discriminator step 33 loss is 0.40994203090667725
# Generator step 34 loss is 2.0680410861968994
# Discriminator step 34 loss is 0.4043944180011749
# Generator step 35 loss is 2.0361149311065674
# Discriminator step 35 loss is 0.4053836464881897
# Generator step 36 loss is 1.9417235851287842
# Discriminator step 36 loss is 0.3882201910018921
# Generator step 37 loss is 1.9145233631134033
# Discriminator step 37 loss is 0.40963539481163025
# Generator step 38 loss is 1.8873608112335205
# Discriminator step 38 loss is 0.3786439597606659
# Generator step 39 loss is 1.9880485534667969
# Discriminator step 39 loss is 0.4060515761375427
# Time for epoch 56 is 3.0476934909820557 sec
# epoch:57
# Generator step 0 loss is 1.8218598365783691
# Discriminator step 0 loss is 0.4148523211479187
# Generator step 1 loss is 1.833903431892395
# Discriminator step 1 loss is 0.4539022445678711
# Generator step 2 loss is 1.9089734554290771
# Discriminator step 2 loss is 0.42809557914733887
# Generator step 3 loss is 2.074695587158203
# Discriminator step 3 loss is 0.46015655994415283
# Generator step 4 loss is 1.8577250242233276
# Discriminator step 4 loss is 0.3821546137332916
# Generator step 5 loss is 1.8874448537826538
# Discriminator step 5 loss is 0.41761094331741333
# Generator step 6 loss is 1.9133048057556152
# Discriminator step 6 loss is 0.41831088066101074
# Generator step 7 loss is 2.002833366394043
# Discriminator step 7 loss is 0.45741045475006104
# Generator step 8 loss is 1.8627371788024902
# Discriminator step 8 loss is 0.40670591592788696
# Generator step 9 loss is 1.8814680576324463
# Discriminator step 9 loss is 0.41493842005729675
# Generator step 10 loss is 1.9761699438095093
# Discriminator step 10 loss is 0.40637877583503723
# Generator step 11 loss is 2.045232057571411
# Discriminator step 11 loss is 0.40703141689300537
# Generator step 12 loss is 2.0449774265289307
# Discriminator step 12 loss is 0.383632630109787
# Generator step 13 loss is 1.9311327934265137
# Discriminator step 13 loss is 0.4051401913166046
# Generator step 14 loss is 1.8388168811798096
# Discriminator step 14 loss is 0.45042186975479126
# Generator step 15 loss is 1.7979283332824707
# Discriminator step 15 loss is 0.4528504014015198
# Generator step 16 loss is 1.8578838109970093
# Discriminator step 16 loss is 0.41656726598739624
# Generator step 17 loss is 1.9883172512054443
# Discriminator step 17 loss is 0.4304494857788086
# Generator step 18 loss is 1.9726874828338623
# Discriminator step 18 loss is 0.4013396203517914
# Generator step 19 loss is 1.866331934928894
# Discriminator step 19 loss is 0.4058143198490143
# Generator step 20 loss is 1.8630841970443726
# Discriminator step 20 loss is 0.42088666558265686
# Generator step 21 loss is 2.0657544136047363
# Discriminator step 21 loss is 0.4075542688369751
# Generator step 22 loss is 1.9770468473434448
# Discriminator step 22 loss is 0.42131471633911133
# Generator step 23 loss is 1.835382103919983
# Discriminator step 23 loss is 0.42648860812187195
# Generator step 24 loss is 1.8459044694900513
# Discriminator step 24 loss is 0.40877360105514526
# Generator step 25 loss is 2.0012452602386475
# Discriminator step 25 loss is 0.3527003228664398
# Generator step 26 loss is 2.218249559402466
# Discriminator step 26 loss is 0.42108792066574097
# Generator step 27 loss is 2.104776382446289
# Discriminator step 27 loss is 0.40107738971710205
# Generator step 28 loss is 1.8369379043579102
# Discriminator step 28 loss is 0.4002074599266052
# Generator step 29 loss is 1.691030502319336
# Discriminator step 29 loss is 0.43475982546806335
# Generator step 30 loss is 2.0078163146972656
# Discriminator step 30 loss is 0.3933391869068146
# Generator step 31 loss is 2.105543613433838
# Discriminator step 31 loss is 0.36375632882118225
# Generator step 32 loss is 2.1171987056732178
# Discriminator step 32 loss is 0.41695308685302734
# Generator step 33 loss is 1.9198873043060303
# Discriminator step 33 loss is 0.3871002197265625
# Generator step 34 loss is 1.9729527235031128
# Discriminator step 34 loss is 0.42060309648513794
# Generator step 35 loss is 1.8476873636245728
# Discriminator step 35 loss is 0.42624518275260925
# Generator step 36 loss is 1.8012863397598267
# Discriminator step 36 loss is 0.43380922079086304
# Generator step 37 loss is 1.9355486631393433
# Discriminator step 37 loss is 0.4313070774078369
# Generator step 38 loss is 2.026654005050659
# Discriminator step 38 loss is 0.41596585512161255
# Generator step 39 loss is 2.0209481716156006
# Discriminator step 39 loss is 0.3873354196548462
# Time for epoch 57 is 2.999201536178589 sec
# epoch:58
# Generator step 0 loss is 1.9569783210754395
# Discriminator step 0 loss is 0.41853344440460205
# Generator step 1 loss is 1.876827597618103
# Discriminator step 1 loss is 0.40659427642822266
# Generator step 2 loss is 1.8249115943908691
# Discriminator step 2 loss is 0.410408616065979
# Generator step 3 loss is 1.883163571357727
# Discriminator step 3 loss is 0.41648662090301514
# Generator step 4 loss is 1.897994041442871
# Discriminator step 4 loss is 0.4537166953086853
# Generator step 5 loss is 1.7585036754608154
# Discriminator step 5 loss is 0.44669443368911743
# Generator step 6 loss is 1.8125994205474854
# Discriminator step 6 loss is 0.4215148687362671
# Generator step 7 loss is 1.9456228017807007
# Discriminator step 7 loss is 0.44496554136276245
# Generator step 8 loss is 1.7342371940612793
# Discriminator step 8 loss is 0.44493287801742554
# Generator step 9 loss is 1.8124260902404785
# Discriminator step 9 loss is 0.42970699071884155
# Generator step 10 loss is 1.9554598331451416
# Discriminator step 10 loss is 0.49292927980422974
# Generator step 11 loss is 1.687027931213379
# Discriminator step 11 loss is 0.47145068645477295
# Generator step 12 loss is 1.6412914991378784
# Discriminator step 12 loss is 0.4701879620552063
# Generator step 13 loss is 1.7033686637878418
# Discriminator step 13 loss is 0.46047377586364746
# Generator step 14 loss is 1.9565426111221313
# Discriminator step 14 loss is 0.4617777168750763
# Generator step 15 loss is 1.9873716831207275
# Discriminator step 15 loss is 0.4473752975463867
# Generator step 16 loss is 1.733603835105896
# Discriminator step 16 loss is 0.46913641691207886
# Generator step 17 loss is 1.6049127578735352
# Discriminator step 17 loss is 0.43503469228744507
# Generator step 18 loss is 1.8710672855377197
# Discriminator step 18 loss is 0.43616122007369995
# Generator step 19 loss is 1.9942026138305664
# Discriminator step 19 loss is 0.4921473264694214
# Generator step 20 loss is 1.842165231704712
# Discriminator step 20 loss is 0.4416319727897644
# Generator step 21 loss is 1.639748215675354
# Discriminator step 21 loss is 0.4478455185890198
# Generator step 22 loss is 1.7920618057250977
# Discriminator step 22 loss is 0.44874274730682373
# Generator step 23 loss is 1.9765238761901855
# Discriminator step 23 loss is 0.4196792542934418
# Generator step 24 loss is 1.922163486480713
# Discriminator step 24 loss is 0.43116194009780884
# Generator step 25 loss is 1.8683642148971558
# Discriminator step 25 loss is 0.4616403877735138
# Generator step 26 loss is 1.6496098041534424
# Discriminator step 26 loss is 0.45222780108451843
# Generator step 27 loss is 1.7762608528137207
# Discriminator step 27 loss is 0.41787660121917725
# Generator step 28 loss is 1.9515063762664795
# Discriminator step 28 loss is 0.39547038078308105
# Generator step 29 loss is 2.0246922969818115
# Discriminator step 29 loss is 0.4148590564727783
# Generator step 30 loss is 1.9570040702819824
# Discriminator step 30 loss is 0.3828529715538025
# Generator step 31 loss is 1.8092225790023804
# Discriminator step 31 loss is 0.390868216753006
# Generator step 32 loss is 1.8824267387390137
# Discriminator step 32 loss is 0.386638343334198
# Generator step 33 loss is 1.975952386856079
# Discriminator step 33 loss is 0.3888511657714844
# Generator step 34 loss is 1.924094557762146
# Discriminator step 34 loss is 0.38713639974594116
# Generator step 35 loss is 1.9785633087158203
# Discriminator step 35 loss is 0.3675038516521454
# Generator step 36 loss is 1.9923906326293945
# Discriminator step 36 loss is 0.371482789516449
# Generator step 37 loss is 1.9392061233520508
# Discriminator step 37 loss is 0.3546459674835205
# Generator step 38 loss is 2.034860134124756
# Discriminator step 38 loss is 0.3538733720779419
# Generator step 39 loss is 2.05373477935791
# Discriminator step 39 loss is 0.2603286802768707
# Time for epoch 58 is 3.053286552429199 sec
# epoch:59
# Generator step 0 loss is 2.2893002033233643
# Discriminator step 0 loss is 0.33619481325149536
# Generator step 1 loss is 2.193549871444702
# Discriminator step 1 loss is 0.36557477712631226
# Generator step 2 loss is 1.819070816040039
# Discriminator step 2 loss is 0.3441848158836365
# Generator step 3 loss is 1.7212337255477905
# Discriminator step 3 loss is 0.3567102253437042
# Generator step 4 loss is 2.013115882873535
# Discriminator step 4 loss is 0.3520265519618988
# Generator step 5 loss is 2.2798662185668945
# Discriminator step 5 loss is 0.3906765878200531
# Generator step 6 loss is 2.215777635574341
# Discriminator step 6 loss is 0.33826011419296265
# Generator step 7 loss is 1.884417176246643
# Discriminator step 7 loss is 0.35296630859375
# Generator step 8 loss is 1.810318112373352
# Discriminator step 8 loss is 0.3651960492134094
# Generator step 9 loss is 1.9971704483032227
# Discriminator step 9 loss is 0.3311880826950073
# Generator step 10 loss is 2.2654049396514893
# Discriminator step 10 loss is 0.3546290397644043
# Generator step 11 loss is 2.1344895362854004
# Discriminator step 11 loss is 0.3590537905693054
# Generator step 12 loss is 1.8436663150787354
# Discriminator step 12 loss is 0.35575342178344727
# Generator step 13 loss is 1.8286304473876953
# Discriminator step 13 loss is 0.3750024437904358
# Generator step 14 loss is 1.9444743394851685
# Discriminator step 14 loss is 0.3902382254600525
# Generator step 15 loss is 2.084031105041504
# Discriminator step 15 loss is 0.3903660178184509
# Generator step 16 loss is 2.0500125885009766
# Discriminator step 16 loss is 0.3584769666194916
# Generator step 17 loss is 1.9080774784088135
# Discriminator step 17 loss is 0.38276612758636475
# Generator step 18 loss is 1.944501519203186
# Discriminator step 18 loss is 0.3841502070426941
# Generator step 19 loss is 1.7550334930419922
# Discriminator step 19 loss is 0.39450255036354065
# Generator step 20 loss is 1.9242448806762695
# Discriminator step 20 loss is 0.4203951954841614
# Generator step 21 loss is 2.1014022827148438
# Discriminator step 21 loss is 0.42897820472717285
# Generator step 22 loss is 1.9165889024734497
# Discriminator step 22 loss is 0.3870905041694641
# Generator step 23 loss is 1.7245597839355469
# Discriminator step 23 loss is 0.4349755644798279
# Generator step 24 loss is 1.780340313911438
# Discriminator step 24 loss is 0.43014806509017944
# Generator step 25 loss is 1.956073522567749
# Discriminator step 25 loss is 0.4289303421974182
# Generator step 26 loss is 1.9073262214660645
# Discriminator step 26 loss is 0.42582249641418457
# Generator step 27 loss is 1.935789704322815
# Discriminator step 27 loss is 0.4508306086063385
# Generator step 28 loss is 1.7347007989883423
# Discriminator step 28 loss is 0.4408697485923767
# Generator step 29 loss is 1.7853949069976807
# Discriminator step 29 loss is 0.4578855335712433
# Generator step 30 loss is 1.82393479347229
# Discriminator step 30 loss is 0.39359721541404724
# Generator step 31 loss is 2.0656416416168213
# Discriminator step 31 loss is 0.41976070404052734
# Generator step 32 loss is 1.9489457607269287
# Discriminator step 32 loss is 0.4522218704223633
# Generator step 33 loss is 1.799709439277649
# Discriminator step 33 loss is 0.4834151864051819
# Generator step 34 loss is 1.5543842315673828
# Discriminator step 34 loss is 0.42522016167640686
# Generator step 35 loss is 1.7915767431259155
# Discriminator step 35 loss is 0.4297751486301422
# Generator step 36 loss is 2.1322848796844482
# Discriminator step 36 loss is 0.44751012325286865
# Generator step 37 loss is 2.0322256088256836
# Discriminator step 37 loss is 0.4266548454761505
# Generator step 38 loss is 1.7670049667358398
# Discriminator step 38 loss is 0.42652255296707153
# Generator step 39 loss is 1.6969999074935913
# Discriminator step 39 loss is 0.4143695831298828
# Time for epoch 59 is 3.0021936893463135 sec
